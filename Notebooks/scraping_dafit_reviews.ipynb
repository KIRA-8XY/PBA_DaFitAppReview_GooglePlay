# %% [markdown]
# # 📘 Scraping DaFit App Reviews
# This notebook collects recent reviews from the DaFit app on the Google Play Store.
# (https://play.google.com/store/apps/details?id=com.crrepa.band.dafit&hl=en_SG)

# %%
# !pip install -q google_play_scraper
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.6 MB/s eta 0:00:00

# %% [markdown]
# ### 🔧 Import Libraries

# %%
from google_play_scraper import reviews_all, Sort
import pandas as pd
import numpy as np

# %% [markdown]
# ### 🧩 Scrape Reviews

# %%
reviews = reviews_all(
    'com.crrepa.band.dafit',
    sleep_milliseconds=0,
    lang='en',
    sort=Sort.NEWEST
)

df = pd.DataFrame(np.array(reviews), columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df.to_csv("scraping_dafit_reviews.csv", index=False)
df.head()
# Out:
#                                reviewId       userName  \
# 0  6de6c806-f71f-42f3-ab64-0a58fec11816  A Google user
# 1  2db5d6c3-0a33-4934-97db-b722f3299d4c  A Google user
# 2  d9227bad-c638-47ea-ba86-502376a410db  A Google user
# 3  0f287cb5-1a93-4e0e-aebc-0b0fb2e8f58e  A Google user
# 4  36d9f404-12d1-4c6c-b65d-d8c0895b66f4  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                                               good      5              0
# 1                                               good      3              0
# 2  for what it does the watch is huge and this ap...      1              0
# ...
